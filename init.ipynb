# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If you imported a project with a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# There's no requirements.txt, so nothing to install. This is the case with most projects.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# if test -f .deepnote/requirements.txt
#   then
#     sed -i '/jupyter/d' .deepnote/requirements.txt
#     pip install -r .deepnote/requirements.txt
#   else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# fi
# Out:
# Requirement already satisfied: attrs==19.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 1)) (19.3.0)
# Collecting backcall==0.1.0
#   Downloading backcall-0.1.0.tar.gz (9.7 kB)
# Requirement already satisfied: bleach==3.1.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 3)) (3.1.5)
# Collecting certifi==2020.4.5.1
#   Downloading certifi-2020.4.5.1-py2.py3-none-any.whl (157 kB)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 7)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 8)) (0.6.0)
# Requirement already satisfied: docopt==0.6.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 9)) (0.6.2)
# Requirement already satisfied: entrypoints==0.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 10)) (0.3)
# Requirement already satisfied: idna==2.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 11)) (2.9)
# Collecting importlib-metadata==1.6.0
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: ipykernel==5.3.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 13)) (5.3.0)
# Collecting ipython==7.14.0
#   Downloading ipython-7.14.0-py3-none-any.whl (782 kB)
# Requirement already satisfied: ipython-genutils==0.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 16)) (7.5.1)
# Requirement already satisfied: jedi==0.17.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 17)) (0.17.0)
# Requirement already satisfied: Jinja2==2.11.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 18)) (2.11.2)
# Requirement already satisfied: joblib==0.15.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 19)) (0.15.1)
# Requirement already satisfied: jsonschema==3.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 20)) (3.2.0)
# Requirement already satisfied: kiwisolver==1.2.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 21)) (1.2.0)
# Requirement already satisfied: MarkupSafe==1.1.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 22)) (1.1.1)
# Requirement already satisfied: matplotlib==3.2.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 23)) (3.2.1)
# Requirement already satisfied: mistune==0.8.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 24)) (0.8.4)
# Requirement already satisfied: nbconvert==5.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 25)) (5.6.1)
# Requirement already satisfied: nbformat==5.0.6 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 26)) (5.0.6)
# Collecting numpy==1.18.4
#   Downloading numpy-1.18.4-cp37-cp37m-manylinux1_x86_64.whl (20.2 MB)
# Requirement already satisfied: packaging==20.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 28)) (20.4)
# Requirement already satisfied: pandas==0.25.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 29)) (0.25.0)
# Requirement already satisfied: pandocfilters==1.4.2 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 30)) (1.4.2)
# Requirement already satisfied: parso==0.7.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 31)) (0.7.0)
# Requirement already satisfied: pexpect==4.8.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 32)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 33)) (0.7.5)
# Requirement already satisfied: pipreqs@ git+https://github.com/deepnote/pipreqs.git@5c94fac42a8ddd19eabd75e3de8e84bb8120afd1 from git+https://github.com/deepnote/pipreqs.git@5c94fac42a8ddd19eabd75e3de8e84bb8120afd1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 34)) (0.4.8)
# Collecting pluggy==0.13.1
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Collecting prometheus-client==0.7.1
#   Downloading prometheus_client-0.7.1.tar.gz (38 kB)
# Requirement already satisfied: prompt-toolkit==3.0.5 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 37)) (3.0.5)
# Requirement already satisfied: ptyprocess==0.6.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 38)) (0.6.0)
# Requirement already satisfied: Pygments==2.6.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 39)) (2.6.1)
# Requirement already satisfied: pyparsing==2.4.7 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 40)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.16.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 41)) (0.16.0)
# Requirement already satisfied: python-dateutil==2.8.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 42)) (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.3.4 in /opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.3.4-py3.7.egg (from -r .deepnote/requirements.txt (line 43)) (0.3.4)
# Requirement already satisfied: python-language-server==0.30.0+39.g60b5005 in /opt/venv/lib/python3.7/site-packages/python_language_server-0.30.0+39.g60b5005-py3.7.egg (from -r .deepnote/requirements.txt (line 44)) (0.30.0+39.g60b5005)
# Requirement already satisfied: pytz==2020.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 45)) (2020.1)
# Requirement already satisfied: pyzmq==19.0.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 46)) (19.0.1)
# Requirement already satisfied: requests==2.23.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 47)) (2.23.0)
# Requirement already satisfied: scikit-learn==0.23.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 48)) (0.23.1)
# Requirement already satisfied: scipy==1.4.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 49)) (1.4.1)
# Requirement already satisfied: Send2Trash==1.5.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 50)) (1.5.0)
# Collecting six==1.14.0
#   Downloading six-1.14.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: terminado==0.8.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 52)) (0.8.3)
# Requirement already satisfied: testpath==0.4.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 53)) (0.4.4)
# Collecting threadpoolctl==2.0.0
#   Downloading threadpoolctl-2.0.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: tornado==6.0.4 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 55)) (6.0.4)
# Requirement already satisfied: traitlets==4.3.3 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 56)) (4.3.3)
# Requirement already satisfied: ujson==1.35 in /opt/venv/lib/python3.7/site-packages/ujson-1.35-py3.7-linux-x86_64.egg (from -r .deepnote/requirements.txt (line 57)) (1.35)
# Requirement already satisfied: urllib3==1.25.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 58)) (1.25.9)
# Collecting wcwidth==0.1.9
#   Downloading wcwidth-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: webencodings==0.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 60)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 61)) (3.5.1)
# Requirement already satisfied: yarg==0.1.9 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 62)) (0.1.9)
# Requirement already satisfied: zipp==3.1.0 in /opt/venv/lib/python3.7/site-packages (from -r .deepnote/requirements.txt (line 63)) (3.1.0)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel==5.3.0->-r .deepnote/requirements.txt (line 13)) (6.1.3)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.7/site-packages (from ipython==7.14.0->-r .deepnote/requirements.txt (line 14)) (46.4.0)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbconvert==5.6.1->-r .deepnote/requirements.txt (line 25)) (4.6.3)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r .deepnote/requirements.txt (line 61)) (7.0.0.dev0)
# Building wheels for collected packages: backcall, prometheus-client
#   Building wheel for backcall (setup.py): started
#   Building wheel for backcall (setup.py): finished with status 'done'
#   Created wheel for backcall: filename=backcall-0.1.0-py3-none-any.whl size=10413 sha256=bd493f4b2ac6d57fdc7aa6d2e5d750d97cb047be0d2323e16c02461eba6a8ccc
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9e/56/4f/da13e448a8a5b8671b2954600d5355cf36e557c7aa5020139b
#   Building wheel for prometheus-client (setup.py): started
#   Building wheel for prometheus-client (setup.py): finished with status 'done'
#   Created wheel for prometheus-client: filename=prometheus_client-0.7.1-py3-none-any.whl size=41404 sha256=15e4402d7d872339d24c97e1bc33f1eb6a65caa008e4ce5ab2f37f592964f29b
#   Stored in directory: /home/jovyan/.cache/pip/wheels/30/0c/26/59ba285bf65dc79d195e9b25e2ddde4c61070422729b0cd914
# Successfully built backcall prometheus-client
# Installing collected packages: backcall, certifi, importlib-metadata, ipython, numpy, pluggy, prometheus-client, six, threadpoolctl, wcwidth
#   Attempting uninstall: backcall
#     Found existing installation: backcall 0.2.0
#     Uninstalling backcall-0.2.0:
#       Successfully uninstalled backcall-0.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.4.5.2
#     Uninstalling certifi-2020.4.5.2:
#       Successfully uninstalled certifi-2020.4.5.2
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 1.6.1
#     Uninstalling importlib-metadata-1.6.1:
#       Successfully uninstalled importlib-metadata-1.6.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.15.0
#     Uninstalling ipython-7.15.0:
#       Successfully uninstalled ipython-7.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.0.0.dev0
#     Uninstalling pluggy-1.0.0.dev0:
#       Successfully uninstalled pluggy-1.0.0.dev0
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus-client 0.8.0
#     Uninstalling prometheus-client-0.8.0:
#       Successfully uninstalled prometheus-client-0.8.0
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.1.0
#     Uninstalling threadpoolctl-2.1.0:
#       Successfully uninstalled threadpoolctl-2.1.0
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.4
#     Uninstalling wcwidth-0.2.4:
#       Successfully uninstalled wcwidth-0.2.4
# Successfully installed backcall-0.1.0 certifi-2020.4.5.1 importlib-metadata-1.6.0 ipython-7.14.0 numpy-1.18.4 pluggy-0.13.1 prometheus-client-0.7.1 six-1.14.0 threadpoolctl-2.0.0 wcwidth-0.1.9
